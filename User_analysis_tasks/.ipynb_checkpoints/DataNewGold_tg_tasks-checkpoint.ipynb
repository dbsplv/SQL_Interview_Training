# %% [markdown]
# # Задачи с Data New Gold tg

# %%
import numpy as np
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
import datetime
con = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/postgres')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N=100000
user_count = 2000
vendor_count = 60


order_id = [i for i in range(N)]
user_id = np.random.randint(0,user_count,N)
vendor_id = np.random.randint(0,vendor_count,N)
products_count = np.random.randint(0,13,N)
products_sum = [products_count[i] * np.random.randint(1,3000) for i in range(N)]

# %%
day= np.random.randint(1,29,N)
month=np.random.randint(1,13,N)
year=[2022 for i in range(N)]

#date = [ str(year[i])+'-'+str(month[i])+'-'+str(day[i]) + ' 01:01:10 UTC'  for i in range(N)]
date = [ datetime.datetime(year[i], month[i], day[i])  for i in range(N)]
date[:5]
# Out:
# [datetime.datetime(2022, 9, 22, 0, 0),
#  datetime.datetime(2022, 4, 26, 0, 0),
#  datetime.datetime(2022, 12, 24, 0, 0),
#  datetime.datetime(2022, 9, 26, 0, 0),
#  datetime.datetime(2022, 3, 3, 0, 0)]

# %%
orders = pd.DataFrame({
    'order_id':order_id,
    'user_id': user_id,
    'vendor_id':vendor_id,
    'products_count': products_count,
    'products_sum': products_sum,
    'date' : date
})

# %%
orders.head()
# Out:
#    order_id  user_id  vendor_id  products_count  products_sum       date
# 0         0      260         19               6         12390 2022-09-22
# 1         1      133         25               7         13461 2022-04-26
# 2         2      697         52               5          5570 2022-12-24
# 3         3      837         17              10         25640 2022-09-26
# 4         4     1641         27               8           264 2022-03-03

# %%
vendor_id = [i for i in range(vendor_count)]
vendor_name = [str(i) for i in range(vendor_count)]
take_rate = np.random.random(vendor_count) *1000

# %%
vendor = pd.DataFrame({
    'vendor_id': vendor_id,
    'vendor_name': vendor_name,
    'take_rate': take_rate
})

# %%
orders.to_sql('orders',con, index=False, if_exists='replace')
vendor.to_sql('vendor',con, index=False, if_exists='replace')

# %% [markdown]
# ## Задание 1
#
# Выведи топ 10 вендоров с самым большим количеством заказов за последний месяц

# %%
sql1='''
select 
    *,
    pg_typeof(date::date ),
    date_trunc('month', date::date)
    
from 
    orders




limit 10

'''

# %%
sel=pd.read_sql(sql1,con)
sel.head(10)
# Out:
#    order_id  user_id  vendor_id  products_count  products_sum       date  \
# 0         0      260         19               6         12390 2022-09-22
# 1         1      133         25               7         13461 2022-04-26
# 2         2      697         52               5          5570 2022-12-24
# 3         3      837         17              10         25640 2022-09-26
# 4         4     1641         27               8           264 2022-03-03
# 5         5     1841         15               5          1005 2022-12-25
# 6         6     1862         29               5         10665 2022-11-22
# 7         7     1337         35               0             0 2022-10-12
# 8         8      500         36               3          4212 2022-11-17
# 9         9      459         38               3          8223 2022-06-06
#
#   pg_typeof                date_trunc
# 0      date 2022-08-31 21:00:00+00:00
# 1      date 2022-03-31 21:00:00+00:00
# 2      date 2022-11-30 21:00:00+00:00
# 3      date 2022-08-31 21:00:00+00:00
# 4      date 2022-02-28 21:00:00+00:00
# 5      date 2022-11-30 21:00:00+00:00
# 6      date 2022-10-31 21:00:00+00:00
# 7      date 2022-09-30 21:00:00+00:00
# 8      date 2022-10-31 21:00:00+00:00
# 9      date 2022-05-31 21:00:00+00:00

# %%
sel.dtypes
# Out:
# order_id                   int64
# user_id                    int64
# vendor_id                  int64
# products_count             int64
# products_sum               int64
# date              datetime64[ns]
# dtype: object

# %% [markdown]
# ## Задание 2
#
# Выведи все рестораны(vendor_name) и количество их заказов

# %%
sql2='''
select 
    vendor.vendor_name,
    count(orders.order_id) as orders_count
from orders

inner join
        vendor
            on orders.vendor_id == vendor.vendor_id

group by
    vendor.vendor_id

'''

# %%
sel2=pd.read_sql(sql2,con)
sel2.head(10)

# %% [markdown]
# ## Задание 3
#
# Выведи всех клиентов, которые не заказывали в КФС(vendor_name = 1) за последний месяц

# %%
sql3='''
select 
    *
from
    orders
    
LEFT OUTER join
        (
        select 
                user_id,
                vendor.vendor_name,
                orders.date
        from orders
        inner join
                vendor
                    on orders.vendor_id == vendor.vendor_id
        where 
            vendor.vendor_name =='1'
                and
             (select 
                    date ((
                        select max(date)
                        from orders
                ), 'start of month')) == date(orders.date, 'start of month')
        ) as sq
        on sq.user_id == orders.user_id
where 
    (select 
                    date ((
                        select max(date)
                        from orders
                ), 'start of month')) == date(orders.date, 'start of month')
            and 
                vendor_id == 1
         
'''

# %%
sel3=pd.read_sql(sql3,con)
sel3.head(30)
